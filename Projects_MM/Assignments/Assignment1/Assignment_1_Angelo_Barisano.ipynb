# %%
from gurobipy import *
import gurobipy as gp

# type declaration
from typing import Dict, List


import pandas as pd

# %load_ext nb_black
# %load_ext lab_black

# %%
combinations_oil_refineries_distributioncenters: Dict[tuple, int] = {
    ("T", "N", "P"): 11 + 11,
    ("T", "C", "P"): 7 + 7,
    ("T", "S", "P"): 2 + 5,
    ("T", "N", "A"): 11 + 7,
    ("T", "C", "A"): 7 + 4,
    ("T", "S", "A"): 2 + 3,
    ("CA", "N", "P"): 7 + 11,
    ("CA", "C", "P"): 4 + 7,
    ("CA", "S", "P"): 8 + 5,
    ("CA", "N", "A"): 7 + 7,
    ("CA", "C", "A"): 4 + 4,
    ("CA", "S", "A"): 8 + 3,
}


# quantity constraint
combinations_oil_refineries_distributioncenters_list = list(
    combinations_oil_refineries_distributioncenters.keys()
)


oil_fields: List[str] = ["T", "CA"]
refineries: List[str] = ["NO", "C", "S"]
distribution_centers: List[str] = ["P", "A"]


# oil_field_limits
oil_field_limits: Dict[str, int] = {"CA": 50000, "T": 10000}


# demand limits
demand_limits: Dict[str, int] = {"P": 20000, "A": 25000}


# set the decision function
model = gp.Model()
model.ModelSense = gp.GRB.MINIMIZE

# set the objective function
obj = {}
for combi in combinations_oil_refineries_distributioncenters_list:
    obj[combi] = model.addVar(
        lb=0,
        obj=combinations_oil_refineries_distributioncenters[combi],
        name="{}".format(str(combi)).replace(" ", ""),
    )

# CONSTRAINT FOR SUPPLY: essenetially: for every combintion with T at beginning; this is <= 10000; and <= for CA
for oil_field in oil_field_limits.keys():
    lhs = 0
    for objective_r in obj.keys():
        if objective_r[0] == oil_field:
            lhs += obj[objective_r]
    model.addConstr(
        lhs <= oil_field_limits[oil_field], name="oil_limit_{}".format(oil_field)
    )

# Constraint for demand
for distro in demand_limits.keys():
    lhs = 0
    for objective_r in obj.keys():
        if objective_r[-1] == distro:
            lhs += obj[objective_r]
    model.addConstr(lhs == demand_limits[distro], name="demand_{}".format(distro))

model.optimize()
if not model.status == gp.GRB.OPTIMAL:
    print("something went wrong")
print("optimal value", model.objval)
model.printAttr("X")
# Out:
# Set parameter Username
# Academic license - for non-commercial use only - expires 2023-11-10
# Gurobi Optimizer version 10.0.0 build v10.0.0rc2 (linux64)
#
# CPU model: 11th Gen Intel(R) Core(TM) i7-1165G7 @ 2.80GHz, instruction set [SSE2|AVX|AVX2|AVX512]
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 4 rows, 12 columns and 24 nonzeros
# Model fingerprint: 0x74384aec
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [5e+00, 2e+01]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+04, 5e+04]
# Presolve removed 4 rows and 12 columns
# Presolve time: 0.00s
# Presolve: All rows and columns removed
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    3.8000000e+05   0.000000e+00   0.000000e+00      0s
#
# Solved in 0 iterations and 0.01 seconds (0.00 work units)
# Optimal objective  3.800000000e+05
# optimal value 380000.0
#
#     Variable            X
# -------------------------
# ('T','S','P')        10000
# ('CA','C','P')        10000
# ('CA','C','A')        25000

# %%
print("Sensitivity Analysis:")
model.printAttr(["X", "Obj", "SAObjLow", "SAObjUP"])
model.printAttr(["RC", "LB", "SALBLow", "SALBUp", "UB", "SAUBLow", "SAUBUp"])
model.printAttr(["Sense", "Slack", "Pi", "RHS", "SARHSLow", "SARHSUp"])
# Out:
# Sensitivity Analysis:
#
#     Variable            X          Obj     SAObjLow      SAObjUP
# ----------------------------------------------------------------
# ('T','N','P')            0           22            7          inf
# ('T','C','P')            0           14            7          inf
# ('T','S','P')        10000            7         -inf            8
# ('T','N','A')            0           18            4          inf
# ('T','C','A')            0           11            4          inf
# ('T','S','A')            0            5            4          inf
# ('CA','N','P')            0           18           11          inf
# ('CA','C','P')        10000           11           10           13
# ('CA','S','P')            0           13           11          inf
# ('CA','N','A')            0           14            8          inf
# ('CA','C','A')        25000            8         -inf            9
# ('CA','S','A')            0           11            8          inf
#
#     Variable           RC           LB      SALBLow       SALBUp           UB      SAUBLow       SAUBUp
# -------------------------------------------------------------------------------------------------------
# ('T','N','P')           15            0         -inf        10000          inf            0          inf
# ('T','C','P')            7            0         -inf        10000          inf            0          inf
# ('T','S','P')            0            0         -inf        10000          inf        10000          inf
# ('T','N','A')           14            0       -10000        10000          inf            0          inf
# ('T','C','A')            7            0       -10000        10000          inf            0          inf
# ('T','S','A')            1            0       -10000        10000          inf            0          inf
# ('CA','N','P')            7            0         -inf        10000          inf            0          inf
# ('CA','C','P')            0            0         -inf        10000          inf        10000          inf
# ('CA','S','P')            2            0         -inf        10000          inf            0          inf
# ('CA','N','A')            6            0         -inf        25000          inf            0          inf
# ('CA','C','A')            0            0         -inf        25000          inf        25000          inf
# ('CA','S','A')            3            0         -inf        25000          inf            0          inf
#
#   Constraint        Sense        Slack           Pi          RHS     SARHSLow      SARHSUp
# ------------------------------------------------------------------------------------------
# oil_limit_CA            <        15000            0        50000        35000          inf
#  oil_limit_T            <            0           -4        10000            0        20000
#     demand_P            =            0           11        20000        10000        35000
#     demand_A            =            0            8        25000            0        40000

# %% [markdown]
# ## Q 3

# %%
from gurobipy import *
import gurobipy as gp

# type declaration
from typing import Dict, List


import pandas as pd

# %load_ext nb_black
# %load_ext lab_black
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In [8], line 11
#       8 import pandas as pd
#      10 # %load_ext nb_black
# ---> 11 get_ipython().run_line_magic('load_ext', 'lab_black')
#
# File ~/.local/lib/python3.11/site-packages/IPython/core/interactiveshell.py:2364, in InteractiveShell.run_line_magic(self, magic_name, line, _stack_depth)
#    2362     kwargs['local_ns'] = self.get_local_scope(stack_depth)
#    2363 with self.builtin_trap:
# -> 2364     result = fn(*args, **kwargs)
#    2365 return result
#
# File ~/.local/lib/python3.11/site-packages/IPython/core/magics/extension.py:33, in ExtensionMagics.load_ext(self, module_str)
#      31 if not module_str:
#      32     raise UsageError('Missing module name.')
# ---> 33 res = self.shell.extension_manager.load_extension(module_str)
#      35 if res == 'already loaded':
#      36     print("The %s extension is already loaded. To reload it, use:" % module_str)
#
# File ~/.local/lib/python3.11/site-packages/IPython/core/extensions.py:76, in ExtensionManager.load_extension(self, module_str)
#      69 """Load an IPython extension by its module name.
#      70
#      71 Returns the string "already loaded" if the extension is already loaded,
#      72 "no load function" if the module doesn't have a load_ipython_extension
#      73 function, or None if it succeeded.
#      74 """
#      75 try:
# ---> 76     return self._load_extension(module_str)
#      77 except ModuleNotFoundError:
#      78     if module_str in BUILTINS_EXTS:
#
# File ~/.local/lib/python3.11/site-packages/IPython/core/extensions.py:91, in ExtensionManager._load_extension(self, module_str)
#      89 with self.shell.builtin_trap:
#      90     if module_str not in sys.modules:
# ---> 91         mod = import_module(module_str)
#      92     mod = sys.modules[module_str]
#      93     if self._call_load_ipython_extension(mod):
#
# File /usr/lib64/python3.11/importlib/__init__.py:126, in import_module(name, package)
#     124             break
#     125         level += 1
# --> 126 return _bootstrap._gcd_import(name[level:], package, level)
#
# File <frozen importlib._bootstrap>:1206, in _gcd_import(name, package, level)
#
# File <frozen importlib._bootstrap>:1178, in _find_and_load(name, import_)
#
# File <frozen importlib._bootstrap>:1142, in _find_and_load_unlocked(name, import_)
#
# ModuleNotFoundError: No module named 'lab_black'

# %%
stores = ["A", "B"]

demand = {
    ("A", 0): 45,
    ("A", 1): 20,
    ("A", 2): 20,
    ("A", 3): 25,
    ("A", 4): 15,
    ("A", 5): 28,
    ("A", 6): 15,
    ("B", 0): 8,
    ("B", 1): 12,
    ("B", 2): 23,
    ("B", 3): 30,
    ("B", 4): 12,
    ("B", 5): 10,
    ("B", 6): 33,
}

days = 7

model = gp.Model()
model.ModelSense = gp.GRB.MINIMIZE

# purchasing day one
Purc_A = model.addVars(days, name="Purc_A", obj=200)
Purc_B = model.addVars(days, name="Purc_B", obj=200)

# "C allocation (5)" from A to B and B to A
cab = model.addVars(days, name="Cab", obj=5)
cba = model.addVars(days, name="Cba", obj=5)

# "E allocation (20)" from A to B and B to A
eab = model.addVars(days, name="Eab", obj=20)
eba = model.addVars(days, name="Eba", obj=20)

# set the function
model.setObjective(
    gp.quicksum(
        ((Purc_A[t] + Purc_B[t]) * 200 + (eab[t] + eba[t]) * 20 + (cab[t] + cba[t]) * 5)
        for t in range(days)
    )
)

Inventory_A = model.addVars(days, name="Inventory_A")
Inventory_B = model.addVars(days, name="Inventory_B")

## inventory management A
# day 1 purchase only; index 0
Inventory_A[0] = Purc_A[0]
# day 2 no purcahse but E allocation: inventory day 2 = Inventory day 1 (t - 1 = 0) + transfers from b at
# day t - 1 - minus all transfers from a to b and from a to b in the 5 € concerns
Inventory_A[1] = Inventory_A[0] + eba[0] - eab[0] - cab[0]
# day 3 and beyond; is essentially the same as above but now you can also receive
for t in range(2, days):
    Inventory_A[t] = (
        Inventory_A[t - 1] + eba[t - 1] + cba[t - 2] - eab[t - 1] - cab[t - 1]
    )

## the same for B just the other way around!
Inventory_B[0] = Purc_B[0]
Inventory_B[1] = Inventory_B[0] + eab[0] - eba[0] - cba[0]
for t in range(2, days):
    Inventory_B[t] = (
        Inventory_B[t - 1] + eab[t - 1] + cab[t - 2] - eba[t - 1] - cba[t - 1]
    )


# enforce that inventory is at least as big as demand on date t for both inventory a and b
for t in range(days):
    model.addConstr(Inventory_A[t] >= demand[("A", t)], name="Inventory_A")

for t in range(days):
    model.addConstr(Inventory_B[t] >= demand[("B", t)], name="Inventory_B")


# only day one can be used for purchasesing
for t in range(1, days):
    lhs = Purc_A[t] + Purc_B[t]
    model.addConstr(lhs == 0)

# only the last day does not work in this case as there cant be two day transfers (the C transfers)
model.addConstr((cab[days - 1] + cba[days - 1]) == 0)


model.optimize()

print("Total Cost:", model.OBJVAL)
model.printAttr(["x"])
# Out:
# Gurobi Optimizer version 10.0.0 build v10.0.0rc2 (linux64)
#
# CPU model: 11th Gen Intel(R) Core(TM) i7-1165G7 @ 2.80GHz, instruction set [SSE2|AVX|AVX2|AVX512]
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 21 rows, 56 columns and 184 nonzeros
# Model fingerprint: 0x16a8f63d
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [5e+00, 2e+02]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [8e+00, 4e+01]
# Presolve removed 9 rows and 32 columns
# Presolve time: 0.00s
# Presolved: 12 rows, 24 columns, 166 nonzeros
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    1.0680000e+04   1.250000e+01   0.000000e+00      0s
#        6    1.1265000e+04   0.000000e+00   0.000000e+00      0s
#
# Solved in 6 iterations and 0.01 seconds (0.00 work units)
# Optimal objective  1.126500000e+04
# Total Cost: 11265.0
#
#     Variable            x
# -------------------------
#    Purc_A[0]           45
#    Purc_B[0]           10
#       Cab[0]           11
#       Cab[1]            7
#       Cba[3]            3
#       Eab[0]            2
#       Eab[5]            6

# %%
print("Sensitivity Analysis:")
model.printAttr(["X", "Obj", "SAObjLow", "SAObjUP"])
model.printAttr(["RC", "LB", "SALBLow", "SALBUp", "UB", "SAUBLow", "SAUBUp"])
model.printAttr(["Sense", "Slack", "Pi", "RHS", "SARHSLow", "SARHSUp"])
# Out:
# Sensitivity Analysis:
#
#     Variable            X          Obj     SAObjLow      SAObjUP
# ----------------------------------------------------------------
#    Purc_A[0]           45          200          180          inf
#    Purc_A[1]            0          200            0          inf
#    Purc_A[2]            0          200            0          inf
#    Purc_A[3]            0          200            0          inf
#    Purc_A[4]            0          200            0          inf
#    Purc_A[5]            0          200            0          inf
#    Purc_A[6]            0          200            0          inf
#    Purc_B[0]           10          200           45          220
#    Purc_B[1]            0          200            0          inf
#    Purc_B[2]            0          200            0          inf
#    Purc_B[3]            0          200            0          inf
#    Purc_B[4]            0          200            0          inf
#    Purc_B[5]            0          200            0          inf
#    Purc_B[6]            0          200            0          inf
#       Cab[0]           11            5            5           20
#       Cab[1]            7            5          -20            5
#       Cab[2]            0            5         -160          inf
#       Cab[3]            0            5           -5          inf
#       Cab[4]            0            5           -5          inf
#       Cab[5]            0            5            0          inf
#       Cab[6]            0            5            0          inf
#       Cba[0]            0            5          -20          inf
#       Cba[1]            0            5           -5          inf
#       Cba[2]            0            5         -160          inf
#       Cba[3]            3            5           -5           20
#       Cba[4]            0            5          -20          inf
#       Cba[5]            0            5          -20          inf
#       Cba[6]            0            5            0          inf
#       Eab[0]            2           20            5          175
#       Eab[1]            0           20            5          inf
#       Eab[2]            0           20            5          inf
#       Eab[3]            0           20           -5          inf
#       Eab[4]            0           20           -5          inf
#       Eab[5]            6           20            0          175
#       Eab[6]            0           20            0          inf
#       Eba[0]            0           20          -20          inf
#       Eba[1]            0           20           -5          inf
#       Eba[2]            0           20           -5          inf
#       Eba[3]            0           20            5          inf
#       Eba[4]            0           20            5          inf
#       Eba[5]            0           20          -20          inf
#       Eba[6]            0           20            0          inf
# Inventory_A[0]            0            0            0          inf
# Inventory_A[1]            0            0            0          inf
# Inventory_A[2]            0            0            0          inf
# Inventory_A[3]            0            0            0          inf
# Inventory_A[4]            0            0            0          inf
# Inventory_A[5]            0            0            0          inf
# Inventory_A[6]            0            0            0          inf
# Inventory_B[0]            0            0            0          inf
# Inventory_B[1]            0            0            0          inf
# Inventory_B[2]            0            0            0          inf
# Inventory_B[3]            0            0            0          inf
# Inventory_B[4]            0            0            0          inf
# Inventory_B[5]            0            0            0          inf
# Inventory_B[6]            0            0            0          inf
#
#     Variable           RC           LB      SALBLow       SALBUp           UB      SAUBLow       SAUBUp
# -------------------------------------------------------------------------------------------------------
#    Purc_A[0]            0            0         -inf           45          inf           45          inf
#    Purc_A[1]          200            0            0            0          inf            0          inf
#    Purc_A[2]          200            0            0            0          inf            0          inf
#    Purc_A[3]          200            0            0            0          inf            0          inf
#    Purc_A[4]          200            0            0            0          inf            0          inf
#    Purc_A[5]          200            0            0            0          inf            0          inf
#    Purc_A[6]          200            0            0            0          inf            0          inf
#    Purc_B[0]            0            0         -inf           10          inf           10          inf
#    Purc_B[1]          200            0            0            0          inf            0          inf
#    Purc_B[2]          200            0            0            0          inf            0          inf
#    Purc_B[3]          200            0            0            0          inf            0          inf
#    Purc_B[4]          200            0            0            0          inf            0          inf
#    Purc_B[5]          200            0            0            0          inf            0          inf
#    Purc_B[6]          200            0            0            0          inf            0          inf
#       Cab[0]            0            0         -inf           11          inf           11          inf
#       Cab[1]            0            0         -inf            7          inf            7          inf
#       Cab[2]          165            0           -2            2          inf            0          inf
#       Cab[3]           10            0           -3           10          inf            0          inf
#       Cab[4]           10            0           -3           15          inf            0          inf
#       Cab[5]            5            0         -inf            7          inf            0          inf
#       Cab[6]            5            0            0            0          inf            0          inf
#       Cba[0]           25            0           -2           12          inf            0          inf
#       Cba[1]           10            0          -11            5          inf            0          inf
#       Cba[2]          165            0           -2            2          inf            0          inf
#       Cba[3]            0            0         -inf            3          inf            3          inf
#       Cba[4]           25            0           -6           17          inf            0          inf
#       Cba[5]           25            0           -6            7          inf            0          inf
#       Cba[6]            5            0            0            0          inf            0          inf
#       Eab[0]            0            0         -inf            2          inf            2          inf
#       Eab[1]           15            0          -12           11          inf            0          inf
#       Eab[2]           15            0           -5            7          inf            0          inf
#       Eab[3]           25            0           -3           10          inf            0          inf
#       Eab[4]           25            0           -3           15          inf            0          inf
#       Eab[5]            0            0         -inf            6          inf            6          inf
#       Eab[6]           20            0         -inf          inf          inf            0          inf
#       Eba[0]           40            0           -2          inf          inf            0          inf
#       Eba[1]           25            0          -11           12          inf            0          inf
#       Eba[2]           25            0           -7            5          inf            0          inf
#       Eba[3]           15            0          -10            3          inf            0          inf
#       Eba[4]           15            0          -15            3          inf            0          inf
#       Eba[5]           40            0           -6          inf          inf            0          inf
#       Eba[6]           20            0         -inf          inf          inf            0          inf
# Inventory_A[0]            0            0         -inf          inf          inf            0          inf
# Inventory_A[1]            0            0         -inf          inf          inf            0          inf
# Inventory_A[2]            0            0         -inf          inf          inf            0          inf
# Inventory_A[3]            0            0         -inf          inf          inf            0          inf
# Inventory_A[4]            0            0         -inf          inf          inf            0          inf
# Inventory_A[5]            0            0         -inf          inf          inf            0          inf
# Inventory_A[6]            0            0         -inf          inf          inf            0          inf
# Inventory_B[0]            0            0         -inf          inf          inf            0          inf
# Inventory_B[1]            0            0         -inf          inf          inf            0          inf
# Inventory_B[2]            0            0         -inf          inf          inf            0          inf
# Inventory_B[3]            0            0         -inf          inf          inf            0          inf
# Inventory_B[4]            0            0         -inf          inf          inf            0          inf
# Inventory_B[5]            0            0         -inf          inf          inf            0          inf
# Inventory_B[6]            0            0         -inf          inf          inf            0          inf
#
#   Constraint        Sense        Slack           Pi          RHS     SARHSLow      SARHSUp
# ------------------------------------------------------------------------------------------
#  Inventory_A            >            0           20           45           43           47
#  Inventory_A            >          -12            0           20         -inf           32
#  Inventory_A            >           -5            0           20         -inf           25
#  Inventory_A            >            0          155           25           23           27
#  Inventory_A            >          -10            0           15         -inf           25
#  Inventory_A            >            0           25           28           25           43
#  Inventory_A            >           -7            0           15         -inf           22
#  Inventory_B            >           -2            0            8         -inf           10
#  Inventory_B            >            0           15           12           10           23
#  Inventory_B            >            0            0           23           12           30
#  Inventory_B            >            0          165           30           28           32
#  Inventory_B            >          -15            0           12         -inf           27
#  Inventory_B            >          -17            0           10         -inf           27
#  Inventory_B            >            0           20           33           27           40
#          R14            =            0            0            0            0            0
#          R15            =            0            0            0            0            0
#          R16            =            0            0            0            0            0
#          R17            =            0            0            0            0            0
#          R18            =            0            0            0            0            0
#          R19            =            0            0            0            0            0
#          R20            =            0            0            0            0            0

# %%
model.write("problem.lp")
with open("problem.lp") as f:
    print(f.read())
# Out:
# Warning: linear constraint 0 and linear constraint 1 have the same name "Inventory_A"
# \ LP format - for model browsing. Use MPS format to capture full model detail.
# Minimize
#   200 Purc_A[0] + 200 Purc_A[1] + 200 Purc_A[2] + 200 Purc_A[3]
#    + 200 Purc_A[4] + 200 Purc_A[5] + 200 Purc_A[6] + 200 Purc_B[0]
#    + 200 Purc_B[1] + 200 Purc_B[2] + 200 Purc_B[3] + 200 Purc_B[4]
#    + 200 Purc_B[5] + 200 Purc_B[6] + 5 Cab[0] + 5 Cab[1] + 5 Cab[2]
#    + 5 Cab[3] + 5 Cab[4] + 5 Cab[5] + 5 Cab[6] + 5 Cba[0] + 5 Cba[1]
#    + 5 Cba[2] + 5 Cba[3] + 5 Cba[4] + 5 Cba[5] + 5 Cba[6] + 20 Eab[0]
#    + 20 Eab[1] + 20 Eab[2] + 20 Eab[3] + 20 Eab[4] + 20 Eab[5] + 20 Eab[6]
#    + 20 Eba[0] + 20 Eba[1] + 20 Eba[2] + 20 Eba[3] + 20 Eba[4] + 20 Eba[5]
#    + 20 Eba[6] + 0 Inventory_A[0] + 0 Inventory_A[1] + 0 Inventory_A[2]
#    + 0 Inventory_A[3] + 0 Inventory_A[4] + 0 Inventory_A[5]
#    + 0 Inventory_A[6] + 0 Inventory_B[0] + 0 Inventory_B[1]
#    + 0 Inventory_B[2] + 0 Inventory_B[3] + 0 Inventory_B[4]
#    + 0 Inventory_B[5] + 0 Inventory_B[6]
# Subject To
#  Inventory_A: Purc_A[0] >= 45
#  Inventory_A: Purc_A[0] - Cab[0] - Eab[0] + Eba[0] >= 20
#  Inventory_A: Purc_A[0] - Cab[0] - Cab[1] + Cba[0] - Eab[0] - Eab[1]
#    + Eba[0] + Eba[1] >= 20
#  Inventory_A: Purc_A[0] - Cab[0] - Cab[1] - Cab[2] + Cba[0] + Cba[1]
#    - Eab[0] - Eab[1] - Eab[2] + Eba[0] + Eba[1] + Eba[2] >= 25
#  Inventory_A: Purc_A[0] - Cab[0] - Cab[1] - Cab[2] - Cab[3] + Cba[0]
#    + Cba[1] + Cba[2] - Eab[0] - Eab[1] - Eab[2] - Eab[3] + Eba[0] + Eba[1]
#    + Eba[2] + Eba[3] >= 15
#  Inventory_A: Purc_A[0] - Cab[0] - Cab[1] - Cab[2] - Cab[3] - Cab[4]
#    + Cba[0] + Cba[1] + Cba[2] + Cba[3] - Eab[0] - Eab[1] - Eab[2] - Eab[3]
#    - Eab[4] + Eba[0] + Eba[1] + Eba[2] + Eba[3] + Eba[4] >= 28
#  Inventory_A: Purc_A[0] - Cab[0] - Cab[1] - Cab[2] - Cab[3] - Cab[4]
#    - Cab[5] + Cba[0] + Cba[1] + Cba[2] + Cba[3] + Cba[4] - Eab[0] - Eab[1]
#    - Eab[2] - Eab[3] - Eab[4] - Eab[5] + Eba[0] + Eba[1] + Eba[2] + Eba[3]
#    + Eba[4] + Eba[5] >= 15
#  Inventory_B: Purc_B[0] >= 8
#  Inventory_B: Purc_B[0] - Cba[0] + Eab[0] - Eba[0] >= 12
#  Inventory_B: Purc_B[0] + Cab[0] - Cba[0] - Cba[1] + Eab[0] + Eab[1]
#    - Eba[0] - Eba[1] >= 23
#  Inventory_B: Purc_B[0] + Cab[0] + Cab[1] - Cba[0] - Cba[1] - Cba[2]
#    + Eab[0] + Eab[1] + Eab[2] - Eba[0] - Eba[1] - Eba[2] >= 30
#  Inventory_B: Purc_B[0] + Cab[0] + Cab[1] + Cab[2] - Cba[0] - Cba[1]
#    - Cba[2] - Cba[3] + Eab[0] + Eab[1] + Eab[2] + Eab[3] - Eba[0] - Eba[1]
#    - Eba[2] - Eba[3] >= 12
#  Inventory_B: Purc_B[0] + Cab[0] + Cab[1] + Cab[2] + Cab[3] - Cba[0]
#    - Cba[1] - Cba[2] - Cba[3] - Cba[4] + Eab[0] + Eab[1] + Eab[2] + Eab[3]
#    + Eab[4] - Eba[0] - Eba[1] - Eba[2] - Eba[3] - Eba[4] >= 10
#  Inventory_B: Purc_B[0] + Cab[0] + Cab[1] + Cab[2] + Cab[3] + Cab[4]
#    - Cba[0] - Cba[1] - Cba[2] - Cba[3] - Cba[4] - Cba[5] + Eab[0] + Eab[1]
#    + Eab[2] + Eab[3] + Eab[4] + Eab[5] - Eba[0] - Eba[1] - Eba[2] - Eba[3]
#    - Eba[4] - Eba[5] >= 33
#  R14: Purc_A[1] + Purc_B[1] = 0
#  R15: Purc_A[2] + Purc_B[2] = 0
#  R16: Purc_A[3] + Purc_B[3] = 0
#  R17: Purc_A[4] + Purc_B[4] = 0
#  R18: Purc_A[5] + Purc_B[5] = 0
#  R19: Purc_A[6] + Purc_B[6] = 0
#  R20: Cab[6] + Cba[6] = 0
# Bounds
# End

# %% [markdown]
# ### 3c

# %%
df = pd.read_csv(
    "/home/angelo/Downloads/sails.csv"
)

# %%
dict_A = {}
dict_B = {}
for index, row in df.iterrows():
    dict_A[("A", row["day"] - 1)] = row["demandA"]

for index, row in df.iterrows():
    dict_B[("B", row["day"] - 1)] = row["demandB"]

dictionary_ab = dict_A | dict_B

# %%
stores = ["A", "B"]
demand = dictionary_ab
days = 365

# %%
model = gp.Model()
model.ModelSense = gp.GRB.MINIMIZE

# purchasing day one
Purc_A = model.addVars(days, name="Purc_A", obj=200)
Purc_B = model.addVars(days, name="Purc_B", obj=200)

# "C allocation (5)" from A to B and B to A
cab = model.addVars(days, name="Cab", obj=5)
cba = model.addVars(days, name="Cba", obj=5)

# "E allocation (20)" from A to B and B to A
eab = model.addVars(days, name="Eab", obj=20)
eba = model.addVars(days, name="Eba", obj=20)

# set the function
model.setObjective(
    gp.quicksum(
        ((Purc_A[t] + Purc_B[t]) * 200 + (eab[t] + eba[t]) * 20 + (cab[t] + cba[t]) * 5)
        for t in range(days)
    )
)


Inventory_A = model.addVars(days, name="Inventory_A")
Inventory_B = model.addVars(days, name="Inventory_B")

## inventory management A
# day 1 purchase only; index 0
Inventory_A[0] = Purc_A[0]
# day 2 no purcahse but E allocation: inventory day 2 = Inventory day 1 (t - 1 = 0) + transfers from b at day t - 1 - minus all transfers from a to b and from a to b in the 5 € concerns
Inventory_A[1] = Inventory_A[0] + eba[0] - eab[0] - cab[0]
# day 3 and beyond; is essentially the same as above but now you can also receive
for t in range(2, days):
    Inventory_A[t] = (
        Inventory_A[t - 1] + eba[t - 1] + cba[t - 2] - eab[t - 1] - cab[t - 1]
    )

## the same for B just the other way around!
Inventory_B[0] = Purc_B[0]
Inventory_B[1] = Inventory_B[0] + eab[0] - eba[0] - cba[0]
for t in range(2, days):
    Inventory_B[t] = (
        Inventory_B[t - 1] + eab[t - 1] + cab[t - 2] - eba[t - 1] - cba[t - 1]
    )


# enforce that inventory is at least as big as demand on date t for both inventory a and b
for t in range(days):
    model.addConstr(Inventory_A[t] >= demand[("A", t)], name="Inventory_A")

for t in range(days):
    model.addConstr(Inventory_B[t] >= demand[("B", t)], name="Inventory_B")

# only day one can be used for purchasesing
for t in range(1, days):
    lhs = Purc_A[t] + Purc_B[t]
    model.addConstr(lhs == 0)

# only the last day does not work in this case as there cant be two day transfers (the C transfers)
model.addConstr((cab[days - 1] + cba[days - 1]) == 0)


model.optimize()

if not model.status == gp.GRB.OPTIMAL:
    print("something went wrong")
print("optimal value", model.objval)
model.printAttr("X")
# Out:
# Gurobi Optimizer version 10.0.0 build v10.0.0rc2 (linux64)
#
# CPU model: 11th Gen Intel(R) Core(TM) i7-1165G7 @ 2.80GHz, instruction set [SSE2|AVX|AVX2|AVX512]
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 1095 rows, 2920 columns and 532172 nonzeros
# Model fingerprint: 0xfd7ccca5
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [5e+00, 2e+02]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+00, 7e+01]
# Presolve removed 367 rows and 1464 columns
# Presolve time: 0.13s
# Presolved: 728 rows, 1456 columns, 531438 nonzeros
#
# Concurrent LP optimizer: dual simplex and barrier
# Showing barrier log only...
#
# Ordering time: 0.00s
#
# Barrier statistics:
#  AA' NZ     : 2.646e+05
#  Factor NZ  : 2.654e+05 (roughly 3 MB of memory)
#  Factor Ops : 1.289e+08 (less than 1 second per iteration)
#  Threads    : 3
#
# Barrier performed 0 iterations in 0.24 seconds (0.13 work units)
# Barrier solve interrupted - model solved by another algorithm
#
#
# Solved with dual simplex
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#       45    2.2850000e+04   0.000000e+00   0.000000e+00      0s
#
# Solved in 45 iterations and 0.26 seconds (0.15 work units)
# Optimal objective  2.285000000e+04
# optimal value 22850.0
#
#     Variable            X
# -------------------------
#    Purc_A[0]           58
#    Purc_B[0]           49
#      Cab[23]            1
#      Cab[26]            5
#      Cab[32]            1
#      Cab[43]           10
#      Cab[62]            3
#      Cab[72]            6
#      Cab[81]            3
#      Cab[94]            4
#     Cab[108]           11
#     Cab[150]            3
#     Cab[173]            6
#     Cab[200]           15
#     Cab[237]           12
#     Cab[247]            7
#     Cab[256]            2
#     Cab[265]            1
#     Cab[293]            8
#     Cab[329]            6
#      Cba[50]            9
#      Cba[54]           12
#      Cba[86]            8
#      Cba[96]            2
#     Cba[117]            8
#     Cba[163]           13
#     Cba[222]            3
#     Cba[233]           13
#     Cba[242]            3
#     Cba[243]            5
#     Cba[252]            8
#     Cba[304]            5
#     Cba[305]            2
#     Cba[350]            4
#     Cba[360]           15
#      Eab[73]           10
#      Eba[74]            5
#     Eba[110]            4

# %%
dict_3c = {}
dict_3c[("A", 0)] = Inventory_A[0].X
for day in range(1, 365):
    if day == 1:
        dict_3c[("A", day)] = (
            dict_3c[("A", day - 1)] + eba[day - 1].X - eab[day - 1].X - cab[day - 1].X
        )
    else:
        dict_3c[("A", day)] = (
            dict_3c[("A", day - 1)]
            + eba[day - 1].X
            - eab[day - 1].X
            + cba[day - 2].X
            - cab[day - 1].X
        )

# %%
dict_3cb = {}
dict_3cb[("B", 0)] = Inventory_B[0].X
for day in range(1, 365):
    if day == 1:
        dict_3cb[("B", day)] = (
            dict_3cb[("B", day - 1)] + eab[day - 1].X - eba[day - 1].X - cba[day - 1].X
        )
    else:
        dict_3cb[("B", day)] = (
            dict_3cb[("B", day - 1)]
            + eab[day - 1].X
            - eba[day - 1].X
            + cab[day - 2].X
            - cba[day - 1].X
        )

# %%
# how many sails did you transport in total using each type of transportation
# service?
# eab
dict_eab = {}
for day in range(365):
    dict_eab[day] = eab[day].X

# eba
dict_eba = {}
for day in range(365):
    dict_eba[day] = eba[day].X

# cab
dict_cab = {}
for day in range(365):
    dict_cab[day] = cab[day].X
# cba
dict_cba = {}
for day in range(365):
    dict_cba[day] = cba[day].X

# %%
sum(list(dict_eab.values()))
# Out:
# 10.0

# %%
sum(list(dict_eba.values()))
# Out:
# 9.0

# %%
sum(list(dict_cab.values()))
# Out:
# 104.0

# %%
sum(list(dict_cba.values()))
# Out:
# 110.0

# %%
print("has")

# %%
print("Sensitivity Analysis:")
model.printAttr(["X", "Obj", "SAObjLow", "SAObjUP"])
model.printAttr(["RC", "LB", "SALBLow", "SALBUp", "UB", "SAUBLow", "SAUBUp"])
model.printAttr(["Sense", "Slack", "Pi", "RHS", "SARHSLow", "SARHSUp"])
# Out:
# Sensitivity Analysis:
#
#     Variable            X          Obj     SAObjLow      SAObjUP
# ----------------------------------------------------------------
#    Purc_A[0]           58          200          195          205
#    Purc_A[1]            0          200            0          inf
#    Purc_A[2]            0          200            0          inf
#    Purc_A[3]            0          200            0          inf
#    Purc_A[4]            0          200            0          inf
#    Purc_A[5]            0          200            0          inf
#    Purc_A[6]            0          200            0          inf
#    Purc_A[7]            0          200            0          inf
#    Purc_A[8]            0          200            0          inf
#    Purc_A[9]            0          200            0          inf
#   Purc_A[10]            0          200            0          inf
#   Purc_A[11]            0          200            0          inf
#   Purc_A[12]            0          200            0          inf
#   Purc_A[13]            0          200            0          inf
#   Purc_A[14]            0          200            0          inf
#   Purc_A[15]            0          200            0          inf
#   Purc_A[16]            0          200            0          inf
#   Purc_A[17]            0          200            0          inf
#   Purc_A[18]            0          200            0          inf
#   Purc_A[19]            0          200            0          inf
#   Purc_A[20]            0          200            0          inf
#   Purc_A[21]            0          200            0          inf
#   Purc_A[22]            0          200            0          inf
#   Purc_A[23]            0          200            0          inf
#   Purc_A[24]            0          200            0          inf
#   Purc_A[25]            0          200            0          inf
#   Purc_A[26]            0          200            0          inf
#   Purc_A[27]            0          200            0          inf
#   Purc_A[28]            0          200            0          inf
#   Purc_A[29]            0          200            0          inf
#   Purc_A[30]            0          200            0          inf
#   Purc_A[31]            0          200            0          inf
#   Purc_A[32]            0          200            0          inf
#   Purc_A[33]            0          200            0          inf
#   Purc_A[34]            0          200            0          inf
#   Purc_A[35]            0          200            0          inf
#   Purc_A[36]            0          200            0          inf
#   Purc_A[37]            0          200            0          inf
#   Purc_A[38]            0          200            0          inf
#   Purc_A[39]            0          200            0          inf
#   Purc_A[40]            0          200            0          inf
#   Purc_A[41]            0          200            0          inf
#   Purc_A[42]            0          200            0          inf
#   Purc_A[43]            0          200            0          inf
#   Purc_A[44]            0          200            0          inf
#   Purc_A[45]            0          200            0          inf
#   Purc_A[46]            0          200            0          inf
#   Purc_A[47]            0          200            0          inf
#   Purc_A[48]            0          200            0          inf
#   Purc_A[49]            0          200            0          inf
#   Purc_A[50]            0          200            0          inf
#   Purc_A[51]            0          200            0          inf
#   Purc_A[52]            0          200            0          inf
#   Purc_A[53]            0          200            0          inf
#   Purc_A[54]            0          200            0          inf
#   Purc_A[55]            0          200            0          inf
#   Purc_A[56]            0          200            0          inf
#   Purc_A[57]            0          200            0          inf
#   Purc_A[58]            0          200            0          inf
#   Purc_A[59]            0          200            0          inf
#   Purc_A[60]            0          200            0          inf
#   Purc_A[61]            0          200            0          inf
#   Purc_A[62]            0          200            0          inf
#   Purc_A[63]            0          200            0          inf
#   Purc_A[64]            0          200            0          inf
#   Purc_A[65]            0          200            0          inf
#   Purc_A[66]            0          200            0          inf
#   Purc_A[67]            0          200            0          inf
#   Purc_A[68]            0          200            0          inf
#   Purc_A[69]            0          200            0          inf
#   Purc_A[70]            0          200            0          inf
#   Purc_A[71]            0          200            0          inf
#   Purc_A[72]            0          200            0          inf
#   Purc_A[73]            0          200            0          inf
#   Purc_A[74]            0          200            0          inf
#   Purc_A[75]            0          200            0          inf
#   Purc_A[76]            0          200            0          inf
#   Purc_A[77]            0          200            0          inf
#   Purc_A[78]            0          200            0          inf
#   Purc_A[79]            0          200            0          inf
#   Purc_A[80]            0          200            0          inf
#   Purc_A[81]            0          200            0          inf
#   Purc_A[82]            0          200            0          inf
#   Purc_A[83]            0          200            0          inf
#   Purc_A[84]            0          200            0          inf
#   Purc_A[85]            0          200            0          inf
#   Purc_A[86]            0          200            0          inf
#   Purc_A[87]            0          200            0          inf
#   Purc_A[88]            0          200            0          inf
#   Purc_A[89]            0          200            0          inf
#   Purc_A[90]            0          200            0          inf
#   Purc_A[91]            0          200            0          inf
#   Purc_A[92]            0          200            0          inf
#   Purc_A[93]            0          200            0          inf
#   Purc_A[94]            0          200            0          inf
#   Purc_A[95]            0          200            0          inf
#   Purc_A[96]            0          200            0          inf
#   Purc_A[97]            0          200            0          inf
#   Purc_A[98]            0          200            0          inf
#   Purc_A[99]            0          200            0          inf
#  Purc_A[100]            0          200            0          inf
#  Purc_A[101]            0          200            0          inf
#  Purc_A[102]            0          200            0          inf
#  Purc_A[103]            0          200            0          inf
#  Purc_A[104]            0          200            0          inf
#  Purc_A[105]            0          200            0          inf
#  Purc_A[106]            0          200            0          inf
#  Purc_A[107]            0          200            0          inf
#  Purc_A[108]            0          200            0          inf
#  Purc_A[109]            0          200            0          inf
#  Purc_A[110]            0          200            0          inf
#  Purc_A[111]            0          200            0          inf
#  Purc_A[112]            0          200            0          inf
#  Purc_A[113]            0          200            0          inf
#  Purc_A[114]            0          200            0          inf
#  Purc_A[115]            0          200            0          inf
#  Purc_A[116]            0          200            0          inf
#  Purc_A[117]            0          200            0          inf
#  Purc_A[118]            0          200            0          inf
#  Purc_A[119]            0          200            0          inf
#  Purc_A[120]            0          200            0          inf
#  Purc_A[121]            0          200            0          inf
#  Purc_A[122]            0          200            0          inf
#  Purc_A[123]            0          200            0          inf
#  Purc_A[124]            0          200            0          inf
#  Purc_A[125]            0          200            0          inf
#  Purc_A[126]            0          200            0          inf
#  Purc_A[127]            0          200            0          inf
#  Purc_A[128]            0          200            0          inf
#  Purc_A[129]            0          200            0          inf
#  Purc_A[130]            0          200            0          inf
#  Purc_A[131]            0          200            0          inf
#  Purc_A[132]            0          200            0          inf
#  Purc_A[133]            0          200            0          inf
#  Purc_A[134]            0          200            0          inf
#  Purc_A[135]            0          200            0          inf
#  Purc_A[136]            0          200            0          inf
#  Purc_A[137]            0          200            0          inf
#  Purc_A[138]            0          200            0          inf
#  Purc_A[139]            0          200            0          inf
#  Purc_A[140]            0          200            0          inf
#  Purc_A[141]            0          200            0          inf
#  Purc_A[142]            0          200            0          inf
#  Purc_A[143]            0          200            0          inf
#  Purc_A[144]            0          200            0          inf
#  Purc_A[145]            0          200            0          inf
#  Purc_A[146]            0          200            0          inf
#  Purc_A[147]            0          200            0          inf
#  Purc_A[148]            0          200            0          inf
#  Purc_A[149]            0          200            0          inf
#  Purc_A[150]            0          200            0          inf
#  Purc_A[151]            0          200            0          inf
#  Purc_A[152]            0          200            0          inf
#  Purc_A[153]            0          200            0          inf
#  Purc_A[154]            0          200            0          inf
#  Purc_A[155]            0          200            0          inf
#  Purc_A[156]            0          200            0          inf
#  Purc_A[157]            0          200            0          inf
#  Purc_A[158]            0          200            0          inf
#  Purc_A[159]            0          200            0          inf
#  Purc_A[160]            0          200            0          inf
#  Purc_A[161]            0          200            0          inf
#  Purc_A[162]            0          200            0          inf
#  Purc_A[163]            0          200            0          inf
#  Purc_A[164]            0          200            0          inf
#  Purc_A[165]            0          200            0          inf
#  Purc_A[166]            0          200            0          inf
#  Purc_A[167]            0          200            0          inf
#  Purc_A[168]            0          200            0          inf
#  Purc_A[169]            0          200            0          inf
#  Purc_A[170]            0          200            0          inf
#  Purc_A[171]            0          200            0          inf
#  Purc_A[172]            0          200            0          inf
#  Purc_A[173]            0          200            0          inf
#  Purc_A[174]            0          200            0          inf
#  Purc_A[175]            0          200            0          inf
#  Purc_A[176]            0          200            0          inf
#  Purc_A[177]            0          200            0          inf
#  Purc_A[178]            0          200            0          inf
#  Purc_A[179]            0          200            0          inf
#  Purc_A[180]            0          200            0          inf
#  Purc_A[181]            0          200            0          inf
#  Purc_A[182]            0          200            0          inf
#  Purc_A[183]            0          200            0          inf
#  Purc_A[184]            0          200            0          inf
#  Purc_A[185]            0          200            0          inf
#  Purc_A[186]            0          200            0          inf
#  Purc_A[187]            0          200            0          inf
#  Purc_A[188]            0          200            0          inf
#  Purc_A[189]            0          200            0          inf
#  Purc_A[190]            0          200            0          inf
#  Purc_A[191]            0          200            0          inf
#  Purc_A[192]            0          200            0          inf
#  Purc_A[193]            0          200            0          inf
#  Purc_A[194]            0          200            0          inf
#  Purc_A[195]            0          200            0          inf
#  Purc_A[196]            0          200            0          inf
#  Purc_A[197]            0          200            0          inf
#  Purc_A[198]            0          200            0          inf
#  Purc_A[199]            0          200            0          inf
#  Purc_A[200]            0          200            0          inf
#  Purc_A[201]            0          200            0          inf
#  Purc_A[202]            0          200            0          inf
#  Purc_A[203]            0          200            0          inf
#  Purc_A[204]            0          200            0          inf
#  Purc_A[205]            0          200            0          inf
#  Purc_A[206]            0          200            0          inf
#  Purc_A[207]            0          200            0          inf
#  Purc_A[208]            0          200            0          inf
#  Purc_A[209]            0          200            0          inf
#  Purc_A[210]            0          200            0          inf
#  Purc_A[211]            0          200            0          inf
#  Purc_A[212]            0          200            0          inf
#  Purc_A[213]            0          200            0          inf
#  Purc_A[214]            0          200            0          inf
#  Purc_A[215]            0          200            0          inf
#  Purc_A[216]            0          200            0          inf
#  Purc_A[217]            0          200            0          inf
#  Purc_A[218]            0          200            0          inf
#  Purc_A[219]            0          200            0          inf
#  Purc_A[220]            0          200            0          inf
#  Purc_A[221]            0          200            0          inf
#  Purc_A[222]            0          200            0          inf
#  Purc_A[223]            0          200            0          inf
#  Purc_A[224]            0          200            0          inf
#  Purc_A[225]            0          200            0          inf
#  Purc_A[226]            0          200            0          inf
#  Purc_A[227]            0          200            0          inf
#  Purc_A[228]            0          200            0          inf
#  Purc_A[229]            0          200            0          inf
#  Purc_A[230]            0          200            0          inf
#  Purc_A[231]            0          200            0          inf
#  Purc_A[232]            0          200            0          inf
#  Purc_A[233]            0          200            0          inf
#  Purc_A[234]            0          200            0          inf
#  Purc_A[235]            0          200            0          inf
#  Purc_A[236]            0          200            0          inf
#  Purc_A[237]            0          200            0          inf
#  Purc_A[238]            0          200            0          inf
#  Purc_A[239]            0          200            0          inf
#  Purc_A[240]            0          200            0          inf
#  Purc_A[241]            0          200            0          inf
#  Purc_A[242]            0          200            0          inf
#  Purc_A[243]            0          200            0          inf
#  Purc_A[244]            0          200            0          inf
#  Purc_A[245]            0          200            0          inf
#  Purc_A[246]            0          200            0          inf
#  Purc_A[247]            0          200            0          inf
#  Purc_A[248]            0          200            0          inf
#  Purc_A[249]            0          200            0          inf
#  Purc_A[250]            0          200            0          inf
#  Purc_A[251]            0          200            0          inf
#  Purc_A[252]            0          200            0          inf
#  Purc_A[253]            0          200            0          inf
#  Purc_A[254]            0          200            0          inf
#  Purc_A[255]            0          200            0          inf
#  Purc_A[256]            0          200            0          inf
#  Purc_A[257]            0          200            0          inf
#  Purc_A[258]            0          200            0          inf
#  Purc_A[259]            0          200            0          inf
#  Purc_A[260]            0          200            0          inf
#  Purc_A[261]            0          200            0          inf
#  Purc_A[262]            0          200            0          inf
#  Purc_A[263]            0          200            0          inf
#  Purc_A[264]            0          200            0          inf
#  Purc_A[265]            0          200            0          inf
#  Purc_A[266]            0          200            0          inf
#  Purc_A[267]            0          200            0          inf
#  Purc_A[268]            0          200            0          inf
#  Purc_A[269]            0          200            0          inf
#  Purc_A[270]            0          200            0          inf
#  Purc_A[271]            0          200            0          inf
#  Purc_A[272]            0          200            0          inf
#  Purc_A[273]            0          200            0          inf
#  Purc_A[274]            0          200            0          inf
#  Purc_A[275]            0          200            0          inf
#  Purc_A[276]            0          200            0          inf
#  Purc_A[277]            0          200            0          inf
#  Purc_A[278]            0          200            0          inf
#  Purc_A[279]            0          200            0          inf
#  Purc_A[280]            0          200            0          inf
#  Purc_A[281]            0          200            0          inf
#  Purc_A[282]            0          200            0          inf
#  Purc_A[283]            0          200            0          inf
#  Purc_A[284]            0          200            0          inf
#  Purc_A[285]            0          200            0          inf
#  Purc_A[286]            0          200            0          inf
#  Purc_A[287]            0          200            0          inf
#  Purc_A[288]            0          200            0          inf
#  Purc_A[289]            0          200            0          inf
#  Purc_A[290]            0          200            0          inf
#  Purc_A[291]            0          200            0          inf
#  Purc_A[292]            0          200            0          inf
#  Purc_A[293]            0          200            0          inf
#  Purc_A[294]            0          200            0          inf
#  Purc_A[295]            0          200            0          inf
#  Purc_A[296]            0          200            0          inf
#  Purc_A[297]            0          200            0          inf
#  Purc_A[298]            0          200            0          inf
#  Purc_A[299]            0          200            0          inf
#  Purc_A[300]            0          200            0          inf
#  Purc_A[301]            0          200            0          inf
#  Purc_A[302]            0          200            0          inf
#  Purc_A[303]            0          200            0          inf
#  Purc_A[304]            0          200            0          inf
#  Purc_A[305]            0          200            0          inf
#  Purc_A[306]            0          200            0          inf
#  Purc_A[307]            0          200            0          inf
#  Purc_A[308]            0          200            0          inf
#  Purc_A[309]            0          200            0          inf
#  Purc_A[310]            0          200            0          inf
#  Purc_A[311]            0          200            0          inf
#  Purc_A[312]            0          200            0          inf
#  Purc_A[313]            0          200            0          inf
#  Purc_A[314]            0          200            0          inf
#  Purc_A[315]            0          200            0          inf
#  Purc_A[316]            0          200            0          inf
#  Purc_A[317]            0          200            0          inf
#  Purc_A[318]            0          200            0          inf
#  Purc_A[319]            0          200            0          inf
#  Purc_A[320]            0          200            0          inf
#  Purc_A[321]            0          200            0          inf
#  Purc_A[322]            0          200            0          inf
#  Purc_A[323]            0          200            0          inf
#  Purc_A[324]            0          200            0          inf
#  Purc_A[325]            0          200            0          inf
#  Purc_A[326]            0          200            0          inf
#  Purc_A[327]            0          200            0          inf
#  Purc_A[328]            0          200            0          inf
#  Purc_A[329]            0          200            0          inf
#  Purc_A[330]            0          200            0          inf
#  Purc_A[331]            0          200            0          inf
#  Purc_A[332]            0          200            0          inf
#  Purc_A[333]            0          200            0          inf
#  Purc_A[334]            0          200            0          inf
#  Purc_A[335]            0          200            0          inf
#  Purc_A[336]            0          200            0          inf
#  Purc_A[337]            0          200            0          inf
#  Purc_A[338]            0          200            0          inf
#  Purc_A[339]            0          200            0          inf
#  Purc_A[340]            0          200            0          inf
#  Purc_A[341]            0          200            0          inf
#  Purc_A[342]            0          200            0          inf
#  Purc_A[343]            0          200            0          inf
#  Purc_A[344]            0          200            0          inf
#  Purc_A[345]            0          200            0          inf
#  Purc_A[346]            0          200            0          inf
#  Purc_A[347]            0          200            0          inf
#  Purc_A[348]            0          200            0          inf
#  Purc_A[349]            0          200            0          inf
#  Purc_A[350]            0          200            0          inf
#  Purc_A[351]            0          200            0          inf
#  Purc_A[352]            0          200            0          inf
#  Purc_A[353]            0          200            0          inf
#  Purc_A[354]            0          200            0          inf
#  Purc_A[355]            0          200            0          inf
#  Purc_A[356]            0          200            0          inf
#  Purc_A[357]            0          200            0          inf
#  Purc_A[358]            0          200            0          inf
#  Purc_A[359]            0          200            0          inf
#  Purc_A[360]            0          200            0          inf
#  Purc_A[361]            0          200            0          inf
#  Purc_A[362]            0          200            0          inf
#  Purc_A[363]            0          200            0          inf
#  Purc_A[364]            0          200            0          inf
#    Purc_B[0]           49          200          195          200
#    Purc_B[1]            0          200            0          inf
#    Purc_B[2]            0          200            0          inf
#    Purc_B[3]            0          200            0          inf
#    Purc_B[4]            0          200            0          inf
#    Purc_B[5]            0          200            0          inf
#    Purc_B[6]            0          200            0          inf
#    Purc_B[7]            0          200            0          inf
#    Purc_B[8]            0          200            0          inf
#    Purc_B[9]            0          200            0          inf
#   Purc_B[10]            0          200            0          inf
#   Purc_B[11]            0          200            0          inf
#   Purc_B[12]            0          200            0          inf
#   Purc_B[13]            0          200            0          inf
#   Purc_B[14]            0          200            0          inf
#   Purc_B[15]            0          200            0          inf
#   Purc_B[16]            0          200            0          inf
#   Purc_B[17]            0          200            0          inf
#   Purc_B[18]            0          200            0          inf
#   Purc_B[19]            0          200            0          inf
#   Purc_B[20]            0          200            0          inf
#   Purc_B[21]            0          200            0          inf
#   Purc_B[22]            0          200            0          inf
#   Purc_B[23]            0          200            0          inf
#   Purc_B[24]            0          200            0          inf
#   Purc_B[25]            0          200            0          inf
#   Purc_B[26]            0          200            0          inf
#   Purc_B[27]            0          200            0          inf
#   Purc_B[28]            0          200            0          inf
#   Purc_B[29]            0          200            0          inf
#   Purc_B[30]            0          200            0          inf
#   Purc_B[31]            0          200            0          inf
#   Purc_B[32]            0          200            0          inf
#   Purc_B[33]            0          200            0          inf
#   Purc_B[34]            0          200            0          inf
#   Purc_B[35]            0          200            0          inf
#   Purc_B[36]            0          200            0          inf
#   Purc_B[37]            0          200            0          inf
#   Purc_B[38]            0          200            0          inf
#   Purc_B[39]            0          200            0          inf
#   Purc_B[40]            0          200            0          inf
#   Purc_B[41]            0          200            0          inf
#   Purc_B[42]            0          200            0          inf
#   Purc_B[43]            0          200            0          inf
#   Purc_B[44]            0          200            0          inf
#   Purc_B[45]            0          200            0          inf
#   Purc_B[46]            0          200            0          inf
#   Purc_B[47]            0          200            0          inf
#   Purc_B[48]            0          200            0          inf
#   Purc_B[49]            0          200            0          inf
#   Purc_B[50]            0          200            0          inf
#   Purc_B[51]            0          200            0          inf
#   Purc_B[52]            0          200            0          inf
#   Purc_B[53]            0          200            0          inf
#   Purc_B[54]            0          200            0          inf
#   Purc_B[55]            0          200            0          inf
#   Purc_B[56]            0          200            0          inf
#   Purc_B[57]            0          200            0          inf
#   Purc_B[58]            0          200            0          inf
#   Purc_B[59]            0          200            0          inf
#   Purc_B[60]            0          200            0          inf
#   Purc_B[61]            0          200            0          inf
#   Purc_B[62]            0          200            0          inf
#   Purc_B[63]            0          200            0          inf
#   Purc_B[64]            0          200            0          inf
#   Purc_B[65]            0          200            0          inf
#   Purc_B[66]            0          200            0          inf
#   Purc_B[67]            0          200            0          inf
#   Purc_B[68]            0          200            0          inf
#   Purc_B[69]            0          200            0          inf
#   Purc_B[70]            0          200            0          inf
#   Purc_B[71]            0          200            0          inf
#   Purc_B[72]            0          200            0          inf
#   Purc_B[73]            0          200            0          inf
#   Purc_B[74]            0          200            0          inf
#   Purc_B[75]            0          200            0          inf
#   Purc_B[76]            0          200            0          inf
#   Purc_B[77]            0          200            0          inf
#   Purc_B[78]            0          200            0          inf
#   Purc_B[79]            0          200            0          inf
#   Purc_B[80]            0          200            0          inf
#   Purc_B[81]            0          200            0          inf
#   Purc_B[82]            0          200            0          inf
#   Purc_B[83]            0          200            0          inf
#   Purc_B[84]            0          200            0          inf
#   Purc_B[85]            0          200            0          inf
#   Purc_B[86]            0          200            0          inf
#   Purc_B[87]            0          200            0          inf
#   Purc_B[88]            0          200            0          inf
#   Purc_B[89]            0          200            0          inf
#   Purc_B[90]            0          200            0          inf
#   Purc_B[91]            0          200            0          inf
#   Purc_B[92]            0          200            0          inf
#   Purc_B[93]            0          200            0          inf
#   Purc_B[94]            0          200            0          inf
#   Purc_B[95]            0          200            0          inf
#   Purc_B[96]            0          200            0          inf
#   Purc_B[97]            0          200            0          inf
#   Purc_B[98]            0          200            0          inf
#   Purc_B[99]            0          200            0          inf
#  Purc_B[100]            0          200            0          inf
#  Purc_B[101]            0          200            0          inf
#  Purc_B[102]            0          200            0          inf
#  Purc_B[103]            0          200            0          inf
#  Purc_B[104]            0          200            0          inf
#  Purc_B[105]            0          200            0          inf
#  Purc_B[106]            0          200            0          inf
#  Purc_B[107]            0          200            0          inf
#  Purc_B[108]            0          200            0          inf
#  Purc_B[109]            0          200            0          inf
#  Purc_B[110]            0          200            0          inf
#  Purc_B[111]            0          200            0          inf
#  Purc_B[112]            0          200            0          inf
#  Purc_B[113]            0          200            0          inf
#  Purc_B[114]            0          200            0          inf
#  Purc_B[115]            0          200            0          inf
#  Purc_B[116]            0          200            0          inf
#  Purc_B[117]            0          200            0          inf
#  Purc_B[118]            0          200            0          inf
#  Purc_B[119]            0          200            0          inf
#  Purc_B[120]            0          200            0          inf
#  Purc_B[121]            0          200            0          inf
#  Purc_B[122]            0          200            0          inf
#  Purc_B[123]            0          200            0          inf
#  Purc_B[124]            0          200            0          inf
#  Purc_B[125]            0          200            0          inf
#  Purc_B[126]            0          200            0          inf
#  Purc_B[127]            0          200            0          inf
#  Purc_B[128]            0          200            0          inf
#  Purc_B[129]            0          200            0          inf
#  Purc_B[130]            0          200            0          inf
#  Purc_B[131]            0          200            0          inf
#  Purc_B[132]            0          200            0          inf
#  Purc_B[133]            0          200            0          inf
#  Purc_B[134]            0          200            0          inf
#  Purc_B[135]            0          200            0          inf
#  Purc_B[136]            0          200            0          inf
#  Purc_B[137]            0          200            0          inf
#  Purc_B[138]            0          200            0          inf
#  Purc_B[139]            0          200            0          inf
#  Purc_B[140]            0          200            0          inf
#  Purc_B[141]            0          200            0          inf
#  Purc_B[142]            0          200            0          inf
#  Purc_B[143]            0          200            0          inf
#  Purc_B[144]            0          200            0          inf
#  Purc_B[145]            0          200            0          inf
#  Purc_B[146]            0          200            0          inf
#  Purc_B[147]            0          200            0          inf
#  Purc_B[148]            0          200            0          inf
#  Purc_B[149]            0          200            0          inf
#  Purc_B[150]            0          200            0          inf
#  Purc_B[151]            0          200            0          inf
#  Purc_B[152]            0          200            0          inf
#  Purc_B[153]            0          200            0          inf
#  Purc_B[154]            0          200            0          inf
#  Purc_B[155]            0          200            0          inf
#  Purc_B[156]            0          200            0          inf
#  Purc_B[157]            0          200            0          inf
#  Purc_B[158]            0          200            0          inf
#  Purc_B[159]            0          200            0          inf
#  Purc_B[160]            0          200            0          inf
#  Purc_B[161]            0          200            0          inf
#  Purc_B[162]            0          200            0          inf
#  Purc_B[163]            0          200            0          inf
#  Purc_B[164]            0          200            0          inf
#  Purc_B[165]            0          200            0          inf
#  Purc_B[166]            0          200            0          inf
#  Purc_B[167]            0          200            0          inf
#  Purc_B[168]            0          200            0          inf
#  Purc_B[169]            0          200            0          inf
#  Purc_B[170]            0          200            0          inf
#  Purc_B[171]            0          200            0          inf
#  Purc_B[172]            0          200            0          inf
#  Purc_B[173]            0          200            0          inf
#  Purc_B[174]            0          200            0          inf
#  Purc_B[175]            0          200            0          inf
#  Purc_B[176]            0          200            0          inf
#  Purc_B[177]            0          200            0          inf
#  Purc_B[178]            0          200            0          inf
#  Purc_B[179]            0          200            0          inf
#  Purc_B[180]            0          200            0          inf
#  Purc_B[181]            0          200            0          inf
#  Purc_B[182]            0          200            0          inf
#  Purc_B[183]            0          200            0          inf
#  Purc_B[184]            0          200            0          inf
#  Purc_B[185]            0          200            0          inf
#  Purc_B[186]            0          200            0          inf
#  Purc_B[187]            0          200            0          inf
#  Purc_B[188]            0          200            0          inf
#  Purc_B[189]            0          200            0          inf
#  Purc_B[190]            0          200            0          inf
#  Purc_B[191]            0          200            0          inf
#  Purc_B[192]            0          200            0          inf
#  Purc_B[193]            0          200            0          inf
#  Purc_B[194]            0          200            0          inf
#  Purc_B[195]            0          200            0          inf
#  Purc_B[196]            0          200            0          inf
#  Purc_B[197]            0          200            0          inf
#  Purc_B[198]            0          200            0          inf
#  Purc_B[199]            0          200            0          inf
#  Purc_B[200]            0          200            0          inf
#  Purc_B[201]            0          200            0          inf
#  Purc_B[202]            0          200            0          inf
#  Purc_B[203]            0          200            0          inf
#  Purc_B[204]            0          200            0          inf
#  Purc_B[205]            0          200            0          inf
#  Purc_B[206]            0          200            0          inf
#  Purc_B[207]            0          200            0          inf
#  Purc_B[208]            0          200            0          inf
#  Purc_B[209]            0          200            0          inf
#  Purc_B[210]            0          200            0          inf
#  Purc_B[211]            0          200            0          inf
#  Purc_B[212]            0          200            0          inf
#  Purc_B[213]            0          200            0          inf
#  Purc_B[214]            0          200            0          inf
#  Purc_B[215]            0          200            0          inf
#  Purc_B[216]            0          200            0          inf
#  Purc_B[217]            0          200            0          inf
#  Purc_B[218]            0          200            0          inf
#  Purc_B[219]            0          200            0          inf
#  Purc_B[220]            0          200            0          inf
#  Purc_B[221]            0          200            0          inf
#  Purc_B[222]            0          200            0          inf
#  Purc_B[223]            0          200            0          inf
#  Purc_B[224]            0          200            0          inf
#  Purc_B[225]            0          200            0          inf
#  Purc_B[226]            0          200            0          inf
#  Purc_B[227]            0          200            0          inf
#  Purc_B[228]            0          200            0          inf
#  Purc_B[229]            0          200            0          inf
#  Purc_B[230]            0          200            0          inf
#  Purc_B[231]            0          200            0          inf
#  Purc_B[232]            0          200            0          inf
#  Purc_B[233]            0          200            0          inf
#  Purc_B[234]            0          200            0          inf
#  Purc_B[235]            0          200            0          inf
#  Purc_B[236]            0          200            0          inf
#  Purc_B[237]            0          200            0          inf
#  Purc_B[238]            0          200            0          inf
#  Purc_B[239]            0          200            0          inf
#  Purc_B[240]            0          200            0          inf
#  Purc_B[241]            0          200            0          inf
#  Purc_B[242]            0          200            0          inf
#  Purc_B[243]            0          200            0          inf
#  Purc_B[244]            0          200            0          inf
#  Purc_B[245]            0          200            0          inf
#  Purc_B[246]            0          200            0          inf
#  Purc_B[247]            0          200            0          inf
#  Purc_B[248]            0          200            0          inf
#  Purc_B[249]            0          200            0          inf
#  Purc_B[250]            0          200            0          inf
#  Purc_B[251]            0          200            0          inf
#  Purc_B[252]            0          200            0          inf
#  Purc_B[253]            0          200            0          inf
#  Purc_B[254]            0          200            0          inf
#  Purc_B[255]            0          200            0          inf
#  Purc_B[256]            0          200            0          inf
#  Purc_B[257]            0          200            0          inf
#  Purc_B[258]            0          200            0          inf
#  Purc_B[259]            0          200            0          inf
#  Purc_B[260]            0          200            0          inf
#  Purc_B[261]            0          200            0          inf
#  Purc_B[262]            0          200            0          inf
#  Purc_B[263]            0          200            0          inf
#  Purc_B[264]            0          200            0          inf
#  Purc_B[265]            0          200            0          inf
#  Purc_B[266]            0          200            0          inf
#  Purc_B[267]            0          200            0          inf
#  Purc_B[268]            0          200            0          inf
#  Purc_B[269]            0          200            0          inf
#  Purc_B[270]            0          200            0          inf
#  Purc_B[271]            0          200            0          inf
#  Purc_B[272]            0          200            0          inf
#  Purc_B[273]            0          200            0          inf
#  Purc_B[274]            0          200            0          inf
#  Purc_B[275]            0          200            0          inf
#  Purc_B[276]            0          200            0          inf
#  Purc_B[277]            0          200            0          inf
#  Purc_B[278]            0          200            0          inf
#  Purc_B[279]            0          200            0          inf
#  Purc_B[280]            0          200            0          inf
#  Purc_B[281]            0          200            0          inf
#  Purc_B[282]            0          200            0          inf
#  Purc_B[283]            0          200            0          inf
#  Purc_B[284]            0          200            0          inf
#  Purc_B[285]            0          200            0          inf
#  Purc_B[286]            0          200            0          inf
#  Purc_B[287]            0          200            0          inf
#  Purc_B[288]            0          200            0          inf
#  Purc_B[289]            0          200            0          inf
#  Purc_B[290]            0          200            0          inf
#  Purc_B[291]            0          200            0          inf
#  Purc_B[292]            0          200            0          inf
#  Purc_B[293]            0          200            0          inf
#  Purc_B[294]            0          200            0          inf
#  Purc_B[295]            0          200            0          inf
#  Purc_B[296]            0          200            0          inf
#  Purc_B[297]            0          200            0          inf
#  Purc_B[298]            0          200            0          inf
#  Purc_B[299]            0          200            0          inf
#  Purc_B[300]            0          200            0          inf
#  Purc_B[301]            0          200            0          inf
#  Purc_B[302]            0          200            0          inf
#  Purc_B[303]            0          200            0          inf
#  Purc_B[304]            0          200            0          inf
#  Purc_B[305]            0          200            0          inf
#  Purc_B[306]            0          200            0          inf
#  Purc_B[307]            0          200            0          inf
#  Purc_B[308]            0          200            0          inf
#  Purc_B[309]            0          200            0          inf
#  Purc_B[310]            0          200            0          inf
#  Purc_B[311]            0          200            0          inf
#  Purc_B[312]            0          200            0          inf
#  Purc_B[313]            0          200            0          inf
#  Purc_B[314]            0          200            0          inf
#  Purc_B[315]            0          200            0          inf
#  Purc_B[316]            0          200            0          inf
#  Purc_B[317]            0          200            0          inf
#  Purc_B[318]            0          200            0          inf
#  Purc_B[319]            0          200            0          inf
#  Purc_B[320]            0          200            0          inf
#  Purc_B[321]            0          200            0          inf
#  Purc_B[322]            0          200            0          inf
#  Purc_B[323]            0          200            0          inf
#  Purc_B[324]            0          200            0          inf
#  Purc_B[325]            0          200            0          inf
#  Purc_B[326]            0          200            0          inf
#  Purc_B[327]            0          200            0          inf
#  Purc_B[328]            0          200            0          inf
#  Purc_B[329]            0          200            0          inf
#  Purc_B[330]            0          200            0          inf
#  Purc_B[331]            0          200            0          inf
#  Purc_B[332]            0          200            0          inf
#  Purc_B[333]            0          200            0          inf
#  Purc_B[334]            0          200            0          inf
#  Purc_B[335]            0          200            0          inf
#  Purc_B[336]            0          200            0          inf
#  Purc_B[337]            0          200            0          inf
#  Purc_B[338]            0          200            0          inf
#  Purc_B[339]            0          200            0          inf
#  Purc_B[340]            0          200            0          inf
#  Purc_B[341]            0          200            0          inf
#  Purc_B[342]            0          200            0          inf
#  Purc_B[343]            0          200            0          inf
#  Purc_B[344]            0          200            0          inf
#  Purc_B[345]            0          200            0          inf
#  Purc_B[346]            0          200            0          inf
#  Purc_B[347]            0          200            0          inf
#  Purc_B[348]            0          200            0          inf
#  Purc_B[349]            0          200            0          inf
#  Purc_B[350]            0          200            0          inf
#  Purc_B[351]            0          200            0          inf
#  Purc_B[352]            0          200            0          inf
#  Purc_B[353]            0          200            0          inf
#  Purc_B[354]            0          200            0          inf
#  Purc_B[355]            0          200            0          inf
#  Purc_B[356]            0          200            0          inf
#  Purc_B[357]            0          200            0          inf
#  Purc_B[358]            0          200            0          inf
# ...
#         R922            =            0            0            0            0            0
#         R923            =            0            0            0            0            0
#         R924            =            0            0            0            0            0
#         R925            =            0            0            0            0            0
#         R926            =            0            0            0            0            0
#         R927            =            0            0            0            0            0
#         R928            =            0            0            0            0            0
#         R929            =            0            0            0            0            0
#         R930            =            0            0            0            0            0
#         R931            =            0            0            0            0            0
#         R932            =            0            0            0            0            0
#         R933            =            0            0            0            0            0
#         R934            =            0            0            0            0            0
#         R935            =            0            0            0            0            0
#         R936            =            0            0            0            0            0
#         R937            =            0            0            0            0            0
#         R938            =            0            0            0            0            0
#         R939            =            0            0            0            0            0
#         R940            =            0            0            0            0            0
#         R941            =            0            0            0            0            0
#         R942            =            0            0            0            0            0
#         R943            =            0            0            0            0            0
#         R944            =            0            0            0            0            0
#         R945            =            0            0            0            0            0
#         R946            =            0            0            0            0            0
#         R947            =            0            0            0            0            0
#         R948            =            0            0            0            0            0
#         R949            =            0            0            0            0            0
#         R950            =            0            0            0            0            0
#         R951            =            0            0            0            0            0
#         R952            =            0            0            0            0            0
#         R953            =            0            0            0            0            0
#         R954            =            0            0            0            0            0
#         R955            =            0            0            0            0            0
#         R956            =            0            0            0            0            0
#         R957            =            0            0            0            0            0
#         R958            =            0            0            0            0            0
#         R959            =            0            0            0            0            0
#         R960            =            0            0            0            0            0
#         R961            =            0            0            0            0            0
#         R962            =            0            0            0            0            0
#         R963            =            0            0            0            0            0
#         R964            =            0            0            0            0            0
#         R965            =            0            0            0            0            0
#         R966            =            0            0            0            0            0
#         R967            =            0            0            0            0            0
#         R968            =            0            0            0            0            0
#         R969            =            0            0            0            0            0
#         R970            =            0            0            0            0            0
#         R971            =            0            0            0            0            0
#         R972            =            0            0            0            0            0
#         R973            =            0            0            0            0            0
#         R974            =            0            0            0            0            0
#         R975            =            0            0            0            0            0
#         R976            =            0            0            0            0            0
#         R977            =            0            0            0            0            0
#         R978            =            0            0            0            0            0
#         R979            =            0            0            0            0            0
#         R980            =            0            0            0            0            0
#         R981            =            0            0            0            0            0
#         R982            =            0            0            0            0            0
#         R983            =            0            0            0            0            0
#         R984            =            0            0            0            0            0
#         R985            =            0            0            0            0            0
#         R986            =            0            0            0            0            0
#         R987            =            0            0            0            0            0
#         R988            =            0            0            0            0            0
#         R989            =            0            0            0            0            0
#         R990            =            0            0            0            0            0
#         R991            =            0            0            0            0            0
#         R992            =            0            0            0            0            0
#         R993            =            0            0            0            0            0
#         R994            =            0            0            0            0            0
#         R995            =            0            0            0            0            0
#         R996            =            0            0            0            0            0
#         R997            =            0            0            0            0            0
#         R998            =            0            0            0            0            0
#         R999            =            0            0            0            0            0
#        R1000            =            0            0            0            0            0
#        R1001            =            0            0            0            0            0
#        R1002            =            0            0            0            0            0
#        R1003            =            0            0            0            0            0
#        R1004            =            0            0            0            0            0
#        R1005            =            0            0            0            0            0
#        R1006            =            0            0            0            0            0
#        R1007            =            0            0            0            0            0
#        R1008            =            0            0            0            0            0
#        R1009            =            0            0            0            0            0
#        R1010            =            0            0            0            0            0
#        R1011            =            0            0            0            0            0
#        R1012            =            0            0            0            0            0
#        R1013            =            0            0            0            0            0
#        R1014            =            0            0            0            0            0
#        R1015            =            0            0            0            0            0
#        R1016            =            0            0            0            0            0
#        R1017            =            0            0            0            0            0
#        R1018            =            0            0            0            0            0
#        R1019            =            0            0            0            0            0
#        R1020            =            0            0            0            0            0
#        R1021            =            0            0            0            0            0
#        R1022            =            0            0            0            0            0
#        R1023            =            0            0            0            0            0
#        R1024            =            0            0            0            0            0
#        R1025            =            0            0            0            0            0
#        R1026            =            0            0            0            0            0
#        R1027            =            0            0            0            0            0
#        R1028            =            0            0            0            0            0
#        R1029            =            0            0            0            0            0
#        R1030            =            0            0            0            0            0
#        R1031            =            0            0            0            0            0
#        R1032            =            0            0            0            0            0
#        R1033            =            0            0            0            0            0
#        R1034            =            0            0            0            0            0
#        R1035            =            0            0            0            0            0
#        R1036            =            0            0            0            0            0
#        R1037            =            0            0            0            0            0
#        R1038            =            0            0            0            0            0
#        R1039            =            0            0            0            0            0
#        R1040            =            0            0            0            0            0
#        R1041            =            0            0            0            0            0
#        R1042            =            0            0            0            0            0
#        R1043            =            0            0            0            0            0
#        R1044            =            0            0            0            0            0
#        R1045            =            0            0            0            0            0
#        R1046            =            0            0            0            0            0
#        R1047            =            0            0            0            0            0
#        R1048            =            0            0            0            0            0
#        R1049            =            0            0            0            0            0
#        R1050            =            0            0            0            0            0
#        R1051            =            0            0            0            0            0
#        R1052            =            0            0            0            0            0
#        R1053            =            0            0            0            0            0
#        R1054            =            0            0            0            0            0
#        R1055            =            0            0            0            0            0
#        R1056            =            0            0            0            0            0
#        R1057            =            0            0            0            0            0
#        R1058            =            0            0            0            0            0
#        R1059            =            0            0            0            0            0
#        R1060            =            0            0            0            0            0
#        R1061            =            0            0            0            0            0
#        R1062            =            0            0            0            0            0
#        R1063            =            0            0            0            0            0
#        R1064            =            0            0            0            0            0
#        R1065            =            0            0            0            0            0
#        R1066            =            0            0            0            0            0
#        R1067            =            0            0            0            0            0
#        R1068            =            0            0            0            0            0
#        R1069            =            0            0            0            0            0
#        R1070            =            0            0            0            0            0
#        R1071            =            0            0            0            0            0
#        R1072            =            0            0            0            0            0
#        R1073            =            0            0            0            0            0
#        R1074            =            0            0            0            0            0
#        R1075            =            0            0            0            0            0
#        R1076            =            0            0            0            0            0
#        R1077            =            0            0            0            0            0
#        R1078            =            0            0            0            0            0
#        R1079            =            0            0            0            0            0
#        R1080            =            0            0            0            0            0
#        R1081            =            0            0            0            0            0
#        R1082            =            0            0            0            0            0
#        R1083            =            0            0            0            0            0
#        R1084            =            0            0            0            0            0
#        R1085            =            0            0            0            0            0
#        R1086            =            0            0            0            0            0
#        R1087            =            0            0            0            0            0
#        R1088            =            0            0            0            0            0
#        R1089            =            0            0            0            0            0
#        R1090            =            0            0            0            0            0
#        R1091            =            0            0            0            0            0
#        R1092            =            0            0            0            0            0
#        R1093            =            0            0            0            0            0
#        R1094            =            0            0            0            0            0
